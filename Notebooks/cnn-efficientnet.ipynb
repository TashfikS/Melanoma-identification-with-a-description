# %% [markdown]
# ### 🛠️ Define Paths and Hyperparameters
# Sets file paths and model training hyperparameters.

# %%
# Define dataset paths and training hyperparameters
PH2_DATASET_TEXT_PATH = "/kaggle/input/ph2dataset/PH2Dataset/PH2_dataset.txt"
PH2_DATASET_GENERATED_CSV_PATH = "/kaggle/working/PH2_dataset.csv"
HAM_METADATA_PATH = "/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv"
PAD_METADATA_PATH = "/kaggle/input/skin-cancer/metadata.csv"
DARM_METADATA_PATH = "/kaggle/input/derm7pt/release_v0/meta/meta.csv"
BASE_DIR = "/kaggle/input"
FINAL_METADATA_PATH = "/kaggle/working/unified_metadata.csv"
AUGMENTED_DATA_PATH = "/kaggle/working/augmented_data/"
AUGMENTED_METADATA_PATH = "/kaggle/working/augmented_metadata.csv"
TRAIN_METADATA_PATH = "/kaggle/working/train_df.csv"
VAL_METADATA_PATH = "/kaggle/working/validation_df.csv"
TEST_METADATA_PATH = "/kaggle/working/test_df.csv"

BATCH = 32
EPOCH = 160
NUM_WORKER = 4
LR = 3e-3
ETA_MIN = 1e-5
T_MAX = 120
WEIGHT_DECAY = 1e-5

# %% [markdown]
# ### 📁 Setup Directory
# Cleans and prepares the directory for storing augmented data.

# %%
# Clean up and create the augmented data directory
# !rm -rf /kaggle/working/augmented_data
# !mkdir /kaggle/working/augmented_data

# %% [markdown]
# ### 📦 From .TXT to .CSV (For PH2 Dataset)
# This cell does the necessary string manupulation to adapt the .CSV format

# %%
# Import required libraries
import re
import csv

# Legend mappings remain the same
clinical_diag_map = {
    "0": "Common Nevus",
    "1": "Atypical Nevus",
    "2": "Melanoma"
}

asymmetry_map = {
    "0": "Fully Symmetric",
    "1": "Symetric in 1 axe",
    "2": "Fully Asymmetric"
}

feature_map = {
    "A": "Absent",
    "AT": "Atypical",
    "P": "Present",
    "T": "Typical"
}

colors_map = {
    "1": "White",
    "2": "Red",
    "3": "Light-Brown",
    "4": "Dark-Brown",
    "5": "Blue-Gray",
    "6": "Black"
}

# Read the file
with open(PH2_DATASET_TEXT_PATH, "r") as f:
    lines = f.readlines()

# Get the header line
header_line = lines[0].strip()
header_line = re.sub(r'^\|\||\|\|$', '', header_line)  # Remove leading/trailing ||

# Split by both single and double pipes
header_parts = re.split(r'\|\||\|', header_line)
header = [part.strip() for part in header_parts if part.strip()]

# Process data rows
processed_rows = []
for line in lines[1:]:
    if not line.strip() or line.startswith("||---"):
        continue

    # Clean the line
    clean_line = line.strip()
    clean_line = re.sub(r'^\|\||\|\|$', '', clean_line)  # Remove leading/trailing ||

    # Split by both single and double pipes
    parts = re.split(r'\|\||\|', clean_line)
    row_data = [part.strip() for part in parts]

    # Create a dictionary for this row with all columns
    row_dict = {}

    # Add data for each column, using empty string for missing values
    for i, field_name in enumerate(header):
        if i >= len(row_data):
            value = ""
        elif i == 2 and row_data[i]:  # Clinical Diagnosis
            value = clinical_diag_map.get(row_data[i], row_data[i])
        elif i == 3 and row_data[i]:  # Asymmetry
            value = asymmetry_map.get(row_data[i], row_data[i])
        elif i >= 4 and i <= 8 and row_data[i]:  # Features
            value = feature_map.get(row_data[i], row_data[i])
        elif i == 9 and row_data[i]:  # Colors
            value = " ".join(colors_map.get(v, v) for v in row_data[i].split())
        else:
            value = row_data[i]

        row_dict[field_name] = value

    processed_rows.append(row_dict)

# In convert-to-csv.py, modify the final section:
# Write to CSV with only first 200 rows
with open(PH2_DATASET_GENERATED_CSV_PATH, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=header)
    writer.writeheader()
    for row in processed_rows[:200]:  # Only write first 200 rows
        writer.writerow(row)

print(f"Conversion complete. CSV saved as {PH2_DATASET_GENERATED_CSV_PATH} with {len(processed_rows)} rows")
# Out:
# Conversion complete. CSV saved as /kaggle/working/PH2_dataset.csv with 220 rows

# %% [markdown]
# ### 📦 Metadata modification & merging
# This cell filters out targeted columns & rows from all datasets and merging the all metadata files after preparing image path

# %%
# Import required libraries
import pandas as pd
import numpy as np
import os

# Load datasets
df_ham = pd.read_csv(HAM_METADATA_PATH)
df_pad = pd.read_csv(PAD_METADATA_PATH)
df_derm7pt = pd.read_csv(DARM_METADATA_PATH)
df_ph2 = pd.read_csv(PH2_DATASET_GENERATED_CSV_PATH)

# Assign Dataset Identifiers explicitly
df_ham['dataset_source'] = 'HAM10000'
df_pad['dataset_source'] = 'PAD-UFES-20'
df_derm7pt['dataset_source'] = 'DERM7PT'
df_ph2['dataset_source'] = 'PH2'

# Explicitly standardize columns
df_ham.rename(columns={'image_id':'image_id', 'dx':'diagnosis'}, inplace=True)
df_pad.rename(columns={'img_id':'image_id','diagnostic':'diagnosis'}, inplace=True)
df_derm7pt.rename(columns={'case_id':'image_id'}, inplace=True)
df_ph2.rename(columns={'Name':'image_id'}, inplace=True)

# Unified Diagnosis Mapping
diagnosis_map = {
    # Benign (0)
    "nevus": 0, "solar lentigo": 0, "dermatofibroma": 0, "vascular lesion": 0, "nev": 0, "sek": 0,
    "seborrheic keratosis": 0,
    "blue nevus": 0, "congenital nevus": 0, "dermal nevus": 0, "seborrheic keratosis": 0,
    "nv": 0, "nevus": 0, "bkl": 0, "benign keratosis": 0, "df": 0, "dermatofibroma": 0,
    "vasc": 0, "vascular": 0,
    "Intradermal Nevus": 0, "common nevus":0,
    # Intermediate Benign (1)
    "atypical melanocytic proliferation": 1, "actinic keratosis": 1, "lichenoid keratosis": 1,
    "ack": 1, "akiec": 1, "atypical nevus":1,
    # Intermediate Melanoma (2)
    "melanoma (in situ)": 2, "melanoma (<0.76 mm)": 2, "lentigo maligna": 2,
    "atypical spitz tumor": 2,
    # Melanoma (3)
    "melanoma": 3, "melanoma metastasis": 3, "melanoma (>0.76 mm)": 3,
    "mel": 3, "Nodular Melanoma": 3, "melanoma (0.76 to 1.5 mm)": 3,
    "melanoma (more than 1.5 mm)": 3,
}

# Explicit mapping for each dataframe individually
df_ham['diagnosis_numeric'] = df_ham['diagnosis'].str.lower().map(diagnosis_map)
df_pad['diagnosis_numeric'] = df_pad['diagnosis'].str.lower().map(diagnosis_map)
df_derm7pt['diagnosis_numeric'] = df_derm7pt['diagnosis'].str.lower().map(diagnosis_map)
df_ph2['diagnosis_numeric'] = df_ph2['Histological Diagnosis'].str.lower().map(diagnosis_map)

# Merge explicitly
unified_df = pd.concat([df_ham, df_pad, df_derm7pt, df_ph2], ignore_index=True)
unified_df.dropna(subset=['diagnosis_numeric'], inplace=True)
print(unified_df["dataset_source"].unique())

# Explicit image path generation
def generate_image_path(row):
    source, image_id = row['dataset_source'], row['image_id']

    if source == 'HAM10000':
        for part in ['HAM10000_images_part_1', 'HAM10000_images_part_2']:
            path = f"{BASE_DIR}/skin-cancer-mnist-ham10000/{part}/{image_id}.jpg"
            if os.path.exists(path):
                return path

    elif source == 'PAD-UFES-20':
        for part in [1,2,3]:
            path = f"{BASE_DIR}/skin-cancer/imgs_part_{part}/imgs_part_{part}/{image_id}"
            if os.path.exists(path):
                return path

    elif source == 'DERM7PT':
        if pd.notnull(row['derm']):
            return f"{BASE_DIR}/derm7pt/release_v0/images/{row['derm']}"
        elif pd.notnull(row['clinic']):
            return f"{BASE_DIR}/derm7pt/release_v0/images/{row['clinic']}"
        else:
            return None

    elif source == 'PH2':
        return f"{BASE_DIR}/ph2dataset/PH2Dataset/PH2_Dataset_images/{image_id}/{image_id}_Dermoscopic_Image/{image_id}.bmp"

unified_df['image_path'] = unified_df.apply(generate_image_path, axis=1)
unified_df.dropna(subset=['image_path', 'diagnosis_numeric'], inplace=True)
print(unified_df["dataset_source"].unique())

unified_df.to_csv(FINAL_METADATA_PATH, index=False)
# Out:
# ['HAM10000' 'PAD-UFES-20' 'DERM7PT' 'PH2']
# ['HAM10000' 'PAD-UFES-20' 'DERM7PT' 'PH2']

# %% [markdown]
# ### 📦 Count Samples
# This cell counts each class samples

# %%
# Import required libraries
import torch

DIAGNOSIS_NUMERIC = "diagnosis_numeric"

class_to_label = {
    0: 'Benign',
    1: 'Intermediate Benign',
    2: 'Intermediate Melanoma',
    3: 'Melanoma'
}

df = pd.read_csv(FINAL_METADATA_PATH)
value_count = df[DIAGNOSIS_NUMERIC].value_counts()
class_counts, class_weight_dict  = {}, {}

for class_num in value_count.index:
    print(f"{class_to_label[class_num]}: {value_count[class_num]}")
    class_counts[int(class_num)] = int(value_count[class_num])
num_classes = len(value_count)
total_samples = sum(value_count)
print(f"Total samples: {total_samples}")
print(f"Class count: {num_classes}")
print(f"Class counts: {class_counts}")
# Out:
# Benign: 8713
# Melanoma: 1277
# Intermediate Benign: 1057
# Intermediate Melanoma: 69
# Total samples: 11116
# Class count: 4
# Class counts: {0: 8713, 3: 1277, 1: 1057, 2: 69}

# %% [markdown]
# ### 📦 Augmentation Definition
# This cell does the augmentation & saves the augmented images

# %%
# Import required libraries
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch
from sklearn.utils.class_weight import compute_class_weight

def generate_augmented_df(original_df, target_count, transform, save_dir):
    """
    Generates augmented images and returns new DataFrame with paths & labels.
    Saves images to disk in save_dir.
    """
    os.makedirs(save_dir, exist_ok=True)
    augmented_records = []
    existing_count = len(original_df)
    needed = target_count - existing_count

    print(f"Original: {existing_count}, Target: {target_count}, Augmenting: {needed}")

    augment_idx = 0
    while len(augmented_records) < needed:
        for idx, row in original_df.iterrows():
            if len(augmented_records) >= needed:
                break

            img_path = row['image_path']
            label = row['diagnosis_numeric']

            image = cv2.imread(img_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            augmented = transform(image=image)['image']

            new_filename = f"aug_{label}_{augment_idx}.jpg"
            save_path = os.path.join(save_dir, new_filename)
            aug_img_np = augmented.permute(1, 2, 0).cpu().numpy()
            aug_img_np = np.clip(aug_img_np * 255.0, 0, 255).astype(np.uint8)
            cv2.imwrite(save_path, cv2.cvtColor(aug_img_np, cv2.COLOR_RGB2BGR))

            augmented_records.append({'image_path': save_path, 'diagnosis_numeric': label})
            augment_idx += 1

    new_df = pd.concat([original_df, pd.DataFrame(augmented_records)], ignore_index=True)
    return new_df

def balance_custom_classes(df, transform, save_root):
    """
    Custom-balanced class augmentation strategy:
    Benign -> 7000 (downsample)
    Melanoma -> 5000 (augment)
    Intermediate Benign -> 3000 (augment)
    Intermediate Melanoma -> 1000 (augment)
    """
    class_targets = {
        0: 7000,  # Benign
        3: 5000,  # Melanoma
        1: 3000,  # Intermediate Benign
        2: 1000   # Intermediate Melanoma
    }

    final_df_list = []

    for cls, target_count in class_targets.items():
        class_df = df[df['diagnosis_numeric'] == cls]
        existing_count = len(class_df)

        print(f"\nClass {cls}: Existing samples = {existing_count}")

        if existing_count > target_count:
            class_df = class_df.sample(target_count, random_state=42).reset_index(drop=True)
            print(f"Downsampled to {target_count}")
            final_df_list.append(class_df)

        elif existing_count < target_count:
            save_dir = os.path.join(save_root, f"aug_class_{cls}")
            class_aug_df = generate_augmented_df(class_df, target_count, transform, save_dir)
            final_df_list.append(class_aug_df)

        else:
            final_df_list.append(class_df)

    final_balanced_df = pd.concat(final_df_list, ignore_index=True)
    return final_balanced_df
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# ### ⚙️ Augmentation Code Execution
# Executes a general part of the augmentation pipeline.

# %%
# Augmentation to apply to the intermediate classes
augment_pipeline = A.Compose([
    A.RandomResizedCrop((224, 224), scale=(0.8, 1.0)),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=30),
    A.RandomBrightnessContrast(p=0.2),
    A.ColorJitter(p=0.3),
    A.Normalize(),
    ToTensorV2()
])

df = pd.read_csv(FINAL_METADATA_PATH)

augmented_metadata_df = balance_custom_classes(df, transform=augment_pipeline, save_root=AUGMENTED_DATA_PATH)
augmented_metadata_df.to_csv(AUGMENTED_METADATA_PATH, index=False)
# Out:
# Class 0: Existing samples = 8713
# Downsampled to 7000
#
# Class 3: Existing samples = 1277
# Original: 1277, Target: 5000, Augmenting: 3723
#
# Class 1: Existing samples = 1057
# Original: 1057, Target: 3000, Augmenting: 1943
#
# Class 2: Existing samples = 69
# Original: 69, Target: 1000, Augmenting: 931

# %% [markdown]
# ### 📦 Count Augmented Samples

# %%
print(augmented_metadata_df['diagnosis_numeric'].value_counts())
# Out:
# diagnosis_numeric
# 0.0    7000
# 3.0    5000
# 1.0    3000
# 2.0    1000
# Name: count, dtype: int64

# %% [markdown]
# ### 📦 Class Weight Function Definition

# %%
def calculate_class_weights(df, label_col='diagnosis_numeric', device='cpu'):
    """
    Automatically compute class weights based on label frequency in the DataFrame.
    """
    labels = df[label_col].values
    classes = np.unique(labels)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=labels)
    return torch.tensor(weights, dtype=torch.float).to(device)

# %% [markdown]
# ### ⚙️ Class Weight Calculation

# %%
# Compute class weights
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_weights = calculate_class_weights(augmented_metadata_df, device=device)
print("Class Weights:", class_weights)
# Out:
# Class Weights: tensor([0.5714, 1.3333, 4.0000, 0.8000], device='cuda:0')

# %% [markdown]
# ### 📦 Dataset splitting
# Train: Test: Validate = 70: 15: 15

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

df = pd.read_csv(AUGMENTED_METADATA_PATH)

# Split explicitly (70% train, 15% val, 15% test)
train_df, temp_df = train_test_split(df, test_size=0.3, stratify=df['diagnosis_numeric'], random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['diagnosis_numeric'], random_state=42)

# Explicitly ensure integer labels after balancing
train_df['diagnosis_numeric'] = train_df['diagnosis_numeric'].astype(int)
val_df['diagnosis_numeric'] = val_df['diagnosis_numeric'].astype(int)
test_df['diagnosis_numeric'] = test_df['diagnosis_numeric'].astype(int)

# Save explicitly
train_df.to_csv(TRAIN_METADATA_PATH, index=False)
val_df.to_csv(VAL_METADATA_PATH, index=False)
test_df.to_csv(TEST_METADATA_PATH, index=False)

# %% [markdown]
# ### 📦 DataLoader Definition

# %%
import torch
from torch.utils.data import DataLoader, Dataset
import cv2
import albumentations as A
from albumentations.pytorch import ToTensorV2

class SkinDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.iloc[idx]['image_path']
        label = self.df.iloc[idx]['diagnosis_numeric']
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        if self.transform:
            image = self.transform(image=image)['image']

        return image, label

transform = augment_pipeline

train_dataset = SkinDataset(train_df, transform)
val_dataset = SkinDataset(val_df, transform)
test_dataset = SkinDataset(test_df, transform)


# DataLoader explicitly defined
train_loader = DataLoader(train_dataset, batch_size=BATCH, shuffle=True, num_workers=NUM_WORKER, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH, shuffle=False, num_workers=NUM_WORKER, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH, shuffle=False, num_workers=NUM_WORKER, pin_memory=True)

# %% [markdown]
# ### 📦 CNN Definition with pretrained=True

# %%
# !pip install timm

import torch
import torch.nn as nn
import timm
from torch.optim.lr_scheduler import CosineAnnealingLR

class CNN_Model_EfficientNetV2(nn.Module):
    def __init__(self, model_name='tf_efficientnetv2_m', num_classes=4):
        super().__init__()
        self.backbone = timm.create_model(model_name, pretrained=True, num_classes=0)
        in_features = self.backbone.num_features
        self.classifier = nn.Linear(in_features, num_classes)

    def forward(self, x):
        x = self.backbone(x)
        return self.classifier(x)

# Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN_Model_EfficientNetV2().to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)

# Optimizer
learning_rate = 1e-4 * (BATCH / 32)
# learning_rate = LR
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=WEIGHT_DECAY)
# scheduler = CosineAnnealingLR(optimizer, T_max=T_MAX, eta_min=ETA_MIN)
scheduler = CosineAnnealingLR(optimizer, T_max=T_MAX)
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (1.0.12)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.20.1+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.29.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->timm) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->timm) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->timm) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->timm) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->timm) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->timm) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2025.1.31)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torchvision->timm) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torchvision->timm) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->torchvision->timm) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->torchvision->timm) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->torchvision->timm) (2024.2.0)
# model.safetensors:   0%|          | 0.00/218M [00:00<?, ?B/s]

# %% [markdown]
# ### 📦 Training

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# Initialize tracking
train_losses, val_accuracies, f1_scores = [], [], []
best_val_accuracy = 0
resume_path = "efficientNetV2_160_model_checkpoint.pth"

# Optional: Resume previous training
# checkpoint = torch.load(resume_path)
# start_epoch = checkpoint['epoch']
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# train_losses = checkpoint['train_losses']
# val_accuracies = checkpoint['val_accuracies']
# f1_scores = checkpoint['f1_scores']
# num_epochs = 50

start_epoch = 0  # 0 if training from scratch
num_epochs = EPOCH

for epoch in range(start_epoch, num_epochs):
    print(f"Starting Epoch {epoch+1}......")
    model.train()
    total_loss = 0
    correct = 0
    total_samples = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        correct += (outputs.argmax(1) == labels).sum().item()
        total_samples += labels.size(0)

    train_accuracy = correct / total_samples
    train_losses.append(total_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

    model.eval()
    val_correct = 0
    val_samples = 0
    true_labels = []
    pred_labels = []
    pred_probs = []

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = outputs.argmax(1)

            val_correct += (preds == labels).sum().item()
            val_samples += labels.size(0)

            true_labels.extend(labels.cpu().numpy())
            pred_labels.extend(preds.cpu().numpy())
            pred_probs.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())

    val_accuracy = val_correct / val_samples
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')
    auc = roc_auc_score(true_labels, pred_probs, multi_class='ovr', average='weighted')

    val_accuracies.append(val_accuracy)
    f1_scores.append(f1)

    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'Precision: {precision:.4f}, Recall (Sensitivity): {recall:.4f}, F1-score: {f1:.4f}, AUC: {auc:.4f}')

    # Save best model
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), "efficientNetV2_160_model_best.pth")
        print("✅ Saved Best Model!")

    # Save checkpoint to resume later
    torch.save({
        'epoch': epoch + 1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'train_losses': train_losses,
        'val_accuracies': val_accuracies,
        'f1_scores': f1_scores
    }, resume_path)

    scheduler.step()
    new_lr = scheduler.get_last_lr()
    print(f"Epoch {epoch+1}, Updated Learning Rate: {new_lr}")
    # train_val_dict["Learning Rate"].append(new_lr)

torch.save(model.state_dict(), "efficientNetV2_160_model_final.pth")
print("✅ Training Completed! Final Model Saved.")

# 📈 Plot & Save metrics
plt.figure(figsize=(10,4))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Val Accuracy")
plt.plot(f1_scores, label="Val F1")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("Validation Accuracy & F1")
plt.legend()

plt.tight_layout()
plt.savefig("training_metrics_plot.png")
plt.show()
# Out:
# Starting Epoch 1......
# Epoch [1/160], Loss: 178.5634, Train Accuracy: 0.7870
# Validation Accuracy: 0.8471
# Precision: 0.8630, Recall (Sensitivity): 0.8471, F1-score: 0.8476, AUC: 0.9689
# ✅ Saved Best Model!
# Epoch 1, Updated Learning Rate: [9.998286624877786e-05]
# Starting Epoch 2......
# Epoch [2/160], Loss: 117.0544, Train Accuracy: 0.8588
# Validation Accuracy: 0.8688
# Precision: 0.8749, Recall (Sensitivity): 0.8688, F1-score: 0.8693, AUC: 0.9734
# ✅ Saved Best Model!
# Epoch 2, Updated Learning Rate: [9.99314767377287e-05]
# Starting Epoch 3......
# Epoch [3/160], Loss: 92.0494, Train Accuracy: 0.8849
# Validation Accuracy: 0.8867
# Precision: 0.8906, Recall (Sensitivity): 0.8867, F1-score: 0.8861, AUC: 0.9797
# ✅ Saved Best Model!
# Epoch 3, Updated Learning Rate: [9.984586668665642e-05]
# Starting Epoch 4......
# Epoch [4/160], Loss: 76.6638, Train Accuracy: 0.9058
# Validation Accuracy: 0.8888
# Precision: 0.8909, Recall (Sensitivity): 0.8888, F1-score: 0.8890, AUC: 0.9784
# ✅ Saved Best Model!
# Epoch 4, Updated Learning Rate: [9.972609476841367e-05]
# Starting Epoch 5......
# Epoch [5/160], Loss: 65.2063, Train Accuracy: 0.9196
# Validation Accuracy: 0.8925
# Precision: 0.8943, Recall (Sensitivity): 0.8925, F1-score: 0.8923, AUC: 0.9807
# ✅ Saved Best Model!
# Epoch 5, Updated Learning Rate: [9.957224306869053e-05]
# Starting Epoch 6......
# Epoch [6/160], Loss: 51.2714, Train Accuracy: 0.9338
# Validation Accuracy: 0.9133
# Precision: 0.9142, Recall (Sensitivity): 0.9133, F1-score: 0.9129, AUC: 0.9856
# ✅ Saved Best Model!
# Epoch 6, Updated Learning Rate: [9.93844170297569e-05]
# Starting Epoch 7......
# Epoch [7/160], Loss: 49.1478, Train Accuracy: 0.9371
# Validation Accuracy: 0.9142
# Precision: 0.9144, Recall (Sensitivity): 0.9142, F1-score: 0.9137, AUC: 0.9840
# ✅ Saved Best Model!
# Epoch 7, Updated Learning Rate: [9.916274537819775e-05]
# Starting Epoch 8......
# Epoch [8/160], Loss: 46.7429, Train Accuracy: 0.9432
# Validation Accuracy: 0.9042
# Precision: 0.9045, Recall (Sensitivity): 0.9042, F1-score: 0.9041, AUC: 0.9838
# Epoch 8, Updated Learning Rate: [9.890738003669029e-05]
# Starting Epoch 9......
# Epoch [9/160], Loss: 38.4505, Train Accuracy: 0.9523
# Validation Accuracy: 0.9008
# Precision: 0.9018, Recall (Sensitivity): 0.9008, F1-score: 0.9005, AUC: 0.9832
# Epoch 9, Updated Learning Rate: [9.861849601988383e-05]
# Starting Epoch 10......
# Epoch [10/160], Loss: 36.5687, Train Accuracy: 0.9541
# Validation Accuracy: 0.9054
# Precision: 0.9074, Recall (Sensitivity): 0.9054, F1-score: 0.9054, AUC: 0.9826
# Epoch 10, Updated Learning Rate: [9.82962913144534e-05]
# Starting Epoch 11......
# Epoch [11/160], Loss: 37.2074, Train Accuracy: 0.9555
# Validation Accuracy: 0.9221
# Precision: 0.9224, Recall (Sensitivity): 0.9221, F1-score: 0.9218, AUC: 0.9869
# ✅ Saved Best Model!
# Epoch 11, Updated Learning Rate: [9.794098674340965e-05]
# Starting Epoch 12......
# Epoch [12/160], Loss: 32.7906, Train Accuracy: 0.9605
# Validation Accuracy: 0.9150
# Precision: 0.9155, Recall (Sensitivity): 0.9150, F1-score: 0.9148, AUC: 0.9868
# Epoch 12, Updated Learning Rate: [9.755282581475767e-05]
# Starting Epoch 13......
# Epoch [13/160], Loss: 30.9657, Train Accuracy: 0.9626
# Validation Accuracy: 0.9258
# Precision: 0.9267, Recall (Sensitivity): 0.9258, F1-score: 0.9258, AUC: 0.9859
# ✅ Saved Best Model!
# Epoch 13, Updated Learning Rate: [9.713207455460892e-05]
# Starting Epoch 14......
# Epoch [14/160], Loss: 24.3359, Train Accuracy: 0.9706
# Validation Accuracy: 0.9146
# Precision: 0.9150, Recall (Sensitivity): 0.9146, F1-score: 0.9146, AUC: 0.9862
# Epoch 14, Updated Learning Rate: [9.667902132486008e-05]
# Starting Epoch 15......
# Epoch [15/160], Loss: 25.2955, Train Accuracy: 0.9697
# Validation Accuracy: 0.9337
# Precision: 0.9339, Recall (Sensitivity): 0.9337, F1-score: 0.9336, AUC: 0.9901
# ✅ Saved Best Model!
# Epoch 15, Updated Learning Rate: [9.619397662556433e-05]
# Starting Epoch 16......
# Epoch [16/160], Loss: 23.7906, Train Accuracy: 0.9721
# Validation Accuracy: 0.9208
# Precision: 0.9208, Recall (Sensitivity): 0.9208, F1-score: 0.9206, AUC: 0.9848
# Epoch 16, Updated Learning Rate: [9.567727288213003e-05]
# Starting Epoch 17......
# Epoch [17/160], Loss: 23.2854, Train Accuracy: 0.9725
# Validation Accuracy: 0.9183
# Precision: 0.9184, Recall (Sensitivity): 0.9183, F1-score: 0.9182, AUC: 0.9862
# Epoch 17, Updated Learning Rate: [9.512926421749304e-05]
# Starting Epoch 18......
# Epoch [18/160], Loss: 21.1305, Train Accuracy: 0.9748
# Validation Accuracy: 0.9254
# Precision: 0.9254, Recall (Sensitivity): 0.9254, F1-score: 0.9253, AUC: 0.9845
# Epoch 18, Updated Learning Rate: [9.455032620941839e-05]
# Starting Epoch 19......
# Epoch [19/160], Loss: 23.1834, Train Accuracy: 0.9740
# Validation Accuracy: 0.9296
# Precision: 0.9306, Recall (Sensitivity): 0.9296, F1-score: 0.9292, AUC: 0.9891
# Epoch 19, Updated Learning Rate: [9.394085563309827e-05]
# Starting Epoch 20......
# Epoch [20/160], Loss: 18.0553, Train Accuracy: 0.9787
# Validation Accuracy: 0.9163
# Precision: 0.9163, Recall (Sensitivity): 0.9163, F1-score: 0.9159, AUC: 0.9844
# Epoch 20, Updated Learning Rate: [9.330127018922194e-05]
# Starting Epoch 21......
# Epoch [21/160], Loss: 21.3331, Train Accuracy: 0.9763
# Validation Accuracy: 0.9225
# Precision: 0.9225, Recall (Sensitivity): 0.9225, F1-score: 0.9224, AUC: 0.9855
# Epoch 21, Updated Learning Rate: [9.263200821770461e-05]
# Starting Epoch 22......
# Epoch [22/160], Loss: 20.2861, Train Accuracy: 0.9740
# Validation Accuracy: 0.9196
# Precision: 0.9203, Recall (Sensitivity): 0.9196, F1-score: 0.9195, AUC: 0.9863
# Epoch 22, Updated Learning Rate: [9.19335283972712e-05]
# Starting Epoch 23......
# Epoch [23/160], Loss: 17.3047, Train Accuracy: 0.9778
# Validation Accuracy: 0.9337
# Precision: 0.9341, Recall (Sensitivity): 0.9337, F1-score: 0.9334, AUC: 0.9873
# Epoch 23, Updated Learning Rate: [9.120630943110079e-05]
# Starting Epoch 24......
# Epoch [24/160], Loss: 15.9392, Train Accuracy: 0.9803
# Validation Accuracy: 0.9321
# Precision: 0.9326, Recall (Sensitivity): 0.9321, F1-score: 0.9322, AUC: 0.9901
# Epoch 24, Updated Learning Rate: [9.045084971874738e-05]
# Starting Epoch 25......
# Epoch [25/160], Loss: 15.6251, Train Accuracy: 0.9812
# Validation Accuracy: 0.9313
# Precision: 0.9319, Recall (Sensitivity): 0.9313, F1-score: 0.9310, AUC: 0.9897
# Epoch 25, Updated Learning Rate: [8.966766701456177e-05]
# Starting Epoch 26......
# Epoch [26/160], Loss: 12.9023, Train Accuracy: 0.9838
# Validation Accuracy: 0.9367
# Precision: 0.9367, Recall (Sensitivity): 0.9367, F1-score: 0.9365, AUC: 0.9899
# ✅ Saved Best Model!
# Epoch 26, Updated Learning Rate: [8.885729807284856e-05]
# Starting Epoch 27......
# Epoch [27/160], Loss: 11.7612, Train Accuracy: 0.9859
# Validation Accuracy: 0.9350
# Precision: 0.9352, Recall (Sensitivity): 0.9350, F1-score: 0.9349, AUC: 0.9899
# Epoch 27, Updated Learning Rate: [8.802029828000156e-05]
# Starting Epoch 28......
# Epoch [28/160], Loss: 16.3193, Train Accuracy: 0.9844
# Validation Accuracy: 0.9012
# Precision: 0.9086, Recall (Sensitivity): 0.9012, F1-score: 0.9017, AUC: 0.9843
# Epoch 28, Updated Learning Rate: [8.715724127386972e-05]
# Starting Epoch 29......
# Epoch [29/160], Loss: 17.0103, Train Accuracy: 0.9799
# Validation Accuracy: 0.9342
# Precision: 0.9344, Recall (Sensitivity): 0.9342, F1-score: 0.9338, AUC: 0.9903
# Epoch 29, Updated Learning Rate: [8.626871855061438e-05]
# Starting Epoch 30......
# Epoch [30/160], Loss: 13.5809, Train Accuracy: 0.9849
# Validation Accuracy: 0.9337
# Precision: 0.9344, Recall (Sensitivity): 0.9337, F1-score: 0.9337, AUC: 0.9902
# Epoch 30, Updated Learning Rate: [8.535533905932738e-05]
# Starting Epoch 31......
# Epoch [31/160], Loss: 11.9010, Train Accuracy: 0.9852
# Validation Accuracy: 0.9371
# Precision: 0.9373, Recall (Sensitivity): 0.9371, F1-score: 0.9369, AUC: 0.9908
# ✅ Saved Best Model!
# Epoch 31, Updated Learning Rate: [8.44177287846877e-05]
# Starting Epoch 32......
# Epoch [32/160], Loss: 14.1494, Train Accuracy: 0.9844
# Validation Accuracy: 0.9200
# Precision: 0.9217, Recall (Sensitivity): 0.9200, F1-score: 0.9200, AUC: 0.9871
# Epoch 32, Updated Learning Rate: [8.345653031794292e-05]
# Starting Epoch 33......
# Epoch [33/160], Loss: 11.4619, Train Accuracy: 0.9865
# Validation Accuracy: 0.9300
# Precision: 0.9303, Recall (Sensitivity): 0.9300, F1-score: 0.9299, AUC: 0.9865
# Epoch 33, Updated Learning Rate: [8.247240241650919e-05]
# Starting Epoch 34......
# Epoch [34/160], Loss: 15.3048, Train Accuracy: 0.9846
# Validation Accuracy: 0.9237
# Precision: 0.9242, Recall (Sensitivity): 0.9237, F1-score: 0.9237, AUC: 0.9863
# Epoch 34, Updated Learning Rate: [8.146601955249188e-05]
# Starting Epoch 35......
# Epoch [35/160], Loss: 13.6180, Train Accuracy: 0.9838
# Validation Accuracy: 0.9321
# Precision: 0.9320, Recall (Sensitivity): 0.9321, F1-score: 0.9320, AUC: 0.9883
# Epoch 35, Updated Learning Rate: [8.043807145043604e-05]
# Starting Epoch 36......
# Epoch [36/160], Loss: 7.1256, Train Accuracy: 0.9903
# Validation Accuracy: 0.9300
# Precision: 0.9303, Recall (Sensitivity): 0.9300, F1-score: 0.9297, AUC: 0.9885
# Epoch 36, Updated Learning Rate: [7.938926261462367e-05]
# Starting Epoch 37......
# Epoch [37/160], Loss: 9.2768, Train Accuracy: 0.9892
# Validation Accuracy: 0.9292
# Precision: 0.9296, Recall (Sensitivity): 0.9292, F1-score: 0.9289, AUC: 0.9877
# Epoch 37, Updated Learning Rate: [7.832031184624166e-05]
# Starting Epoch 38......
# Epoch [38/160], Loss: 10.5062, Train Accuracy: 0.9871
# Validation Accuracy: 0.9354
# Precision: 0.9357, Recall (Sensitivity): 0.9354, F1-score: 0.9352, AUC: 0.9884
# Epoch 38, Updated Learning Rate: [7.723195175075138e-05]
# Starting Epoch 39......
# Epoch [39/160], Loss: 6.9379, Train Accuracy: 0.9921
# Validation Accuracy: 0.9237
# Precision: 0.9242, Recall (Sensitivity): 0.9237, F1-score: 0.9235, AUC: 0.9870
# Epoch 39, Updated Learning Rate: [7.612492823579746e-05]
# Starting Epoch 40......
# Epoch [40/160], Loss: 11.3478, Train Accuracy: 0.9862
# Validation Accuracy: 0.9350
# Precision: 0.9350, Recall (Sensitivity): 0.9350, F1-score: 0.9349, AUC: 0.9885
# Epoch 40, Updated Learning Rate: [7.500000000000002e-05]
# Starting Epoch 41......
# Epoch [41/160], Loss: 8.1918, Train Accuracy: 0.9892
# Validation Accuracy: 0.9358
# Precision: 0.9361, Recall (Sensitivity): 0.9358, F1-score: 0.9358, AUC: 0.9868
# Epoch 41, Updated Learning Rate: [7.385793801298045e-05]
# Starting Epoch 42......
# Epoch [42/160], Loss: 12.5866, Train Accuracy: 0.9882
# Validation Accuracy: 0.9313
# Precision: 0.9313, Recall (Sensitivity): 0.9313, F1-score: 0.9311, AUC: 0.9876
# Epoch 42, Updated Learning Rate: [7.269952498697736e-05]
# Starting Epoch 43......
# Epoch [43/160], Loss: 8.5749, Train Accuracy: 0.9912
# Validation Accuracy: 0.9379
# Precision: 0.9380, Recall (Sensitivity): 0.9379, F1-score: 0.9378, AUC: 0.9904
# ✅ Saved Best Model!
# Epoch 43, Updated Learning Rate: [7.152555484041477e-05]
# Starting Epoch 44......
# Epoch [44/160], Loss: 6.7820, Train Accuracy: 0.9914
# Validation Accuracy: 0.9442
# Precision: 0.9446, Recall (Sensitivity): 0.9442, F1-score: 0.9441, AUC: 0.9908
# ✅ Saved Best Model!
# Epoch 44, Updated Learning Rate: [7.033683215379002e-05]
# Starting Epoch 45......
# Epoch [45/160], Loss: 7.5931, Train Accuracy: 0.9910
# Validation Accuracy: 0.9296
# Precision: 0.9304, Recall (Sensitivity): 0.9296, F1-score: 0.9292, AUC: 0.9879
# Epoch 45, Updated Learning Rate: [6.91341716182545e-05]
# Starting Epoch 46......
# Epoch [46/160], Loss: 6.6872, Train Accuracy: 0.9913
# Validation Accuracy: 0.9375
# Precision: 0.9376, Recall (Sensitivity): 0.9375, F1-score: 0.9375, AUC: 0.9900
# Epoch 46, Updated Learning Rate: [6.791839747726503e-05]
# Starting Epoch 47......
# Epoch [47/160], Loss: 6.2319, Train Accuracy: 0.9927
# Validation Accuracy: 0.9354
# Precision: 0.9360, Recall (Sensitivity): 0.9354, F1-score: 0.9351, AUC: 0.9905
# Epoch 47, Updated Learning Rate: [6.669034296168855e-05]
# Starting Epoch 48......
# Epoch [48/160], Loss: 7.0767, Train Accuracy: 0.9914
# Validation Accuracy: 0.9392
# Precision: 0.9392, Recall (Sensitivity): 0.9392, F1-score: 0.9392, AUC: 0.9907
# Epoch 48, Updated Learning Rate: [6.545084971874738e-05]
# Starting Epoch 49......
# Epoch [49/160], Loss: 5.9535, Train Accuracy: 0.9927
# Validation Accuracy: 0.9267
# Precision: 0.9272, Recall (Sensitivity): 0.9267, F1-score: 0.9268, AUC: 0.9903
# Epoch 49, Updated Learning Rate: [6.420076723519615e-05]
# Starting Epoch 50......
# Epoch [50/160], Loss: 7.9446, Train Accuracy: 0.9921
# Validation Accuracy: 0.9275
# Precision: 0.9284, Recall (Sensitivity): 0.9275, F1-score: 0.9274, AUC: 0.9882
# Epoch 50, Updated Learning Rate: [6.294095225512605e-05]
# Starting Epoch 51......
# Epoch [51/160], Loss: 6.2108, Train Accuracy: 0.9929
# Validation Accuracy: 0.9421
# Precision: 0.9424, Recall (Sensitivity): 0.9421, F1-score: 0.9419, AUC: 0.9909
# Epoch 51, Updated Learning Rate: [6.167226819279528e-05]
# Starting Epoch 52......
# Epoch [52/160], Loss: 7.8518, Train Accuracy: 0.9919
# Validation Accuracy: 0.9304
# Precision: 0.9309, Recall (Sensitivity): 0.9304, F1-score: 0.9302, AUC: 0.9893
# Epoch 52, Updated Learning Rate: [6.0395584540887963e-05]
# Starting Epoch 53......
# Epoch [53/160], Loss: 4.7143, Train Accuracy: 0.9944
# Validation Accuracy: 0.9433
# Precision: 0.9435, Recall (Sensitivity): 0.9433, F1-score: 0.9432, AUC: 0.9912
# Epoch 53, Updated Learning Rate: [5.9111776274607377e-05]
# Starting Epoch 54......
# Epoch [54/160], Loss: 5.6412, Train Accuracy: 0.9938
# Validation Accuracy: 0.9354
# Precision: 0.9354, Recall (Sensitivity): 0.9354, F1-score: 0.9352, AUC: 0.9892
# Epoch 54, Updated Learning Rate: [5.7821723252011545e-05]
# Starting Epoch 55......
# Epoch [55/160], Loss: 5.8012, Train Accuracy: 0.9940
# Validation Accuracy: 0.9454
# Precision: 0.9456, Recall (Sensitivity): 0.9454, F1-score: 0.9454, AUC: 0.9918
# ✅ Saved Best Model!
# Epoch 55, Updated Learning Rate: [5.6526309611002574e-05]
# Starting Epoch 56......
# Epoch [56/160], Loss: 4.5542, Train Accuracy: 0.9950
# Validation Accuracy: 0.9471
# Precision: 0.9471, Recall (Sensitivity): 0.9471, F1-score: 0.9471, AUC: 0.9893
# ✅ Saved Best Model!
# Epoch 56, Updated Learning Rate: [5.5226423163382674e-05]
# Starting Epoch 57......
# Epoch [57/160], Loss: 3.0431, Train Accuracy: 0.9962
# Validation Accuracy: 0.9363
# Precision: 0.9363, Recall (Sensitivity): 0.9363, F1-score: 0.9361, AUC: 0.9892
# Epoch 57, Updated Learning Rate: [5.392295478639225e-05]
# Starting Epoch 58......
# Epoch [58/160], Loss: 4.6361, Train Accuracy: 0.9948
# Validation Accuracy: 0.9342
# Precision: 0.9343, Recall (Sensitivity): 0.9342, F1-score: 0.9341, AUC: 0.9885
# Epoch 58, Updated Learning Rate: [5.261679781214718e-05]
# Starting Epoch 59......
# Epoch [59/160], Loss: 5.5462, Train Accuracy: 0.9939
# Validation Accuracy: 0.9400
# Precision: 0.9406, Recall (Sensitivity): 0.9400, F1-score: 0.9397, AUC: 0.9891
# Epoch 59, Updated Learning Rate: [5.130884741539365e-05]
# Starting Epoch 60......
# Epoch [60/160], Loss: 6.1626, Train Accuracy: 0.9934
# Validation Accuracy: 0.9383
# Precision: 0.9390, Recall (Sensitivity): 0.9383, F1-score: 0.9379, AUC: 0.9909
# Epoch 60, Updated Learning Rate: [5.000000000000001e-05]
# Starting Epoch 61......
# Epoch [61/160], Loss: 4.6001, Train Accuracy: 0.9942
# Validation Accuracy: 0.9467
# Precision: 0.9472, Recall (Sensitivity): 0.9467, F1-score: 0.9465, AUC: 0.9913
# Epoch 61, Updated Learning Rate: [4.8691152584606346e-05]
# Starting Epoch 62......
# Epoch [62/160], Loss: 3.6103, Train Accuracy: 0.9962
# Validation Accuracy: 0.9375
# Precision: 0.9374, Recall (Sensitivity): 0.9375, F1-score: 0.9374, AUC: 0.9907
# Epoch 62, Updated Learning Rate: [4.7383202187852815e-05]
# Starting Epoch 63......
# Epoch [63/160], Loss: 4.3191, Train Accuracy: 0.9959
# Validation Accuracy: 0.9387
# Precision: 0.9392, Recall (Sensitivity): 0.9387, F1-score: 0.9385, AUC: 0.9905
# Epoch 63, Updated Learning Rate: [4.607704521360776e-05]
# Starting Epoch 64......
# Epoch [64/160], Loss: 2.8630, Train Accuracy: 0.9964
# Validation Accuracy: 0.9433
# Precision: 0.9433, Recall (Sensitivity): 0.9433, F1-score: 0.9432, AUC: 0.9901
# Epoch 64, Updated Learning Rate: [4.477357683661734e-05]
# Starting Epoch 65......
# Epoch [65/160], Loss: 4.3623, Train Accuracy: 0.9960
# Validation Accuracy: 0.9292
# Precision: 0.9310, Recall (Sensitivity): 0.9292, F1-score: 0.9292, AUC: 0.9898
# Epoch 65, Updated Learning Rate: [4.347369038899744e-05]
# Starting Epoch 66......
# Epoch [66/160], Loss: 4.8809, Train Accuracy: 0.9948
# Validation Accuracy: 0.9450
# Precision: 0.9452, Recall (Sensitivity): 0.9450, F1-score: 0.9449, AUC: 0.9909
# Epoch 66, Updated Learning Rate: [4.217827674798846e-05]
# Starting Epoch 67......
# Epoch [67/160], Loss: 3.5712, Train Accuracy: 0.9962
# Validation Accuracy: 0.9446
# Precision: 0.9448, Recall (Sensitivity): 0.9446, F1-score: 0.9445, AUC: 0.9919
# Epoch 67, Updated Learning Rate: [4.0888223725392635e-05]
# Starting Epoch 68......
# Epoch [68/160], Loss: 2.9204, Train Accuracy: 0.9969
# Validation Accuracy: 0.9425
# Precision: 0.9427, Recall (Sensitivity): 0.9425, F1-score: 0.9424, AUC: 0.9914
# Epoch 68, Updated Learning Rate: [3.960441545911203e-05]
# Starting Epoch 69......
# Epoch [69/160], Loss: 3.3372, Train Accuracy: 0.9962
# Validation Accuracy: 0.9383
# Precision: 0.9385, Recall (Sensitivity): 0.9383, F1-score: 0.9383, AUC: 0.9894
# Epoch 69, Updated Learning Rate: [3.8327731807204733e-05]
# Starting Epoch 70......
# Epoch [70/160], Loss: 2.2405, Train Accuracy: 0.9968
# Validation Accuracy: 0.9392
# Precision: 0.9394, Recall (Sensitivity): 0.9392, F1-score: 0.9390, AUC: 0.9897
# Epoch 70, Updated Learning Rate: [3.705904774487397e-05]
# Starting Epoch 71......
# Epoch [71/160], Loss: 1.8191, Train Accuracy: 0.9979
# Validation Accuracy: 0.9479
# Precision: 0.9480, Recall (Sensitivity): 0.9479, F1-score: 0.9478, AUC: 0.9919
# ✅ Saved Best Model!
# Epoch 71, Updated Learning Rate: [3.579923276480387e-05]
# Starting Epoch 72......
# Epoch [72/160], Loss: 2.9183, Train Accuracy: 0.9966
# Validation Accuracy: 0.9437
# Precision: 0.9443, Recall (Sensitivity): 0.9437, F1-score: 0.9438, AUC: 0.9909
# Epoch 72, Updated Learning Rate: [3.4549150281252636e-05]
# Starting Epoch 73......
# Epoch [73/160], Loss: 2.0417, Train Accuracy: 0.9976
# Validation Accuracy: 0.9442
# Precision: 0.9442, Recall (Sensitivity): 0.9442, F1-score: 0.9441, AUC: 0.9917
# Epoch 73, Updated Learning Rate: [3.330965703831146e-05]
# Starting Epoch 74......
# Epoch [74/160], Loss: 3.7706, Train Accuracy: 0.9959
# Validation Accuracy: 0.9408
# Precision: 0.9411, Recall (Sensitivity): 0.9408, F1-score: 0.9407, AUC: 0.9907
# Epoch 74, Updated Learning Rate: [3.208160252273499e-05]
# Starting Epoch 75......
# Epoch [75/160], Loss: 3.5209, Train Accuracy: 0.9971
# Validation Accuracy: 0.9492
# Precision: 0.9496, Recall (Sensitivity): 0.9492, F1-score: 0.9489, AUC: 0.9913
# ✅ Saved Best Model!
# Epoch 75, Updated Learning Rate: [3.086582838174552e-05]
# Starting Epoch 76......
# Epoch [76/160], Loss: 2.8942, Train Accuracy: 0.9976
# Validation Accuracy: 0.9458
# Precision: 0.9460, Recall (Sensitivity): 0.9458, F1-score: 0.9457, AUC: 0.9907
# Epoch 76, Updated Learning Rate: [2.9663167846210005e-05]
# Starting Epoch 77......
# Epoch [77/160], Loss: 2.8637, Train Accuracy: 0.9969
# Validation Accuracy: 0.9471
# Precision: 0.9471, Recall (Sensitivity): 0.9471, F1-score: 0.9470, AUC: 0.9911
# Epoch 77, Updated Learning Rate: [2.8474445159585262e-05]
# Starting Epoch 78......
# Epoch [78/160], Loss: 1.4823, Train Accuracy: 0.9980
# Validation Accuracy: 0.9425
# Precision: 0.9426, Recall (Sensitivity): 0.9425, F1-score: 0.9424, AUC: 0.9900
# Epoch 78, Updated Learning Rate: [2.730047501302267e-05]
# Starting Epoch 79......
# Epoch [79/160], Loss: 1.2893, Train Accuracy: 0.9981
# Validation Accuracy: 0.9429
# Precision: 0.9436, Recall (Sensitivity): 0.9429, F1-score: 0.9426, AUC: 0.9905
# Epoch 79, Updated Learning Rate: [2.6142061987019584e-05]
# Starting Epoch 80......
# Epoch [80/160], Loss: 2.9161, Train Accuracy: 0.9971
# Validation Accuracy: 0.9417
# Precision: 0.9420, Recall (Sensitivity): 0.9417, F1-score: 0.9416, AUC: 0.9910
# Epoch 80, Updated Learning Rate: [2.5000000000000018e-05]
# Starting Epoch 81......
# Epoch [81/160], Loss: 2.2015, Train Accuracy: 0.9975
# Validation Accuracy: 0.9429
# Precision: 0.9430, Recall (Sensitivity): 0.9429, F1-score: 0.9427, AUC: 0.9906
# Epoch 81, Updated Learning Rate: [2.3875071764202566e-05]
# Starting Epoch 82......
# Epoch [82/160], Loss: 1.2766, Train Accuracy: 0.9984
# Validation Accuracy: 0.9517
# Precision: 0.9517, Recall (Sensitivity): 0.9517, F1-score: 0.9516, AUC: 0.9928
# ✅ Saved Best Model!
# Epoch 82, Updated Learning Rate: [2.2768048249248668e-05]
# Starting Epoch 83......
# Epoch [83/160], Loss: 1.4775, Train Accuracy: 0.9982
# Validation Accuracy: 0.9437
# Precision: 0.9438, Recall (Sensitivity): 0.9437, F1-score: 0.9437, AUC: 0.9915
# Epoch 83, Updated Learning Rate: [2.1679688153758353e-05]
# Starting Epoch 84......
# Epoch [84/160], Loss: 1.1345, Train Accuracy: 0.9986
# Validation Accuracy: 0.9437
# Precision: 0.9438, Recall (Sensitivity): 0.9437, F1-score: 0.9436, AUC: 0.9925
# Epoch 84, Updated Learning Rate: [2.0610737385376356e-05]
# Starting Epoch 85......
# Epoch [85/160], Loss: 1.1953, Train Accuracy: 0.9985
# Validation Accuracy: 0.9446
# Precision: 0.9449, Recall (Sensitivity): 0.9446, F1-score: 0.9444, AUC: 0.9921
# Epoch 85, Updated Learning Rate: [1.9561928549563975e-05]
# Starting Epoch 86......
# Epoch [86/160], Loss: 1.7456, Train Accuracy: 0.9988
# Validation Accuracy: 0.9504
# Precision: 0.9505, Recall (Sensitivity): 0.9504, F1-score: 0.9503, AUC: 0.9916
# Epoch 86, Updated Learning Rate: [1.8533980447508144e-05]
# Starting Epoch 87......
# Epoch [87/160], Loss: 1.2922, Train Accuracy: 0.9984
# Validation Accuracy: 0.9483
# Precision: 0.9486, Recall (Sensitivity): 0.9483, F1-score: 0.9482, AUC: 0.9925
# Epoch 87, Updated Learning Rate: [1.752759758349083e-05]
# Starting Epoch 88......
# Epoch [88/160], Loss: 0.9845, Train Accuracy: 0.9988
# Validation Accuracy: 0.9442
# Precision: 0.9441, Recall (Sensitivity): 0.9442, F1-score: 0.9441, AUC: 0.9915
# Epoch 88, Updated Learning Rate: [1.6543469682057113e-05]
# Starting Epoch 89......
# Epoch [89/160], Loss: 1.9903, Train Accuracy: 0.9981
# Validation Accuracy: 0.9471
# Precision: 0.9472, Recall (Sensitivity): 0.9471, F1-score: 0.9469, AUC: 0.9916
# Epoch 89, Updated Learning Rate: [1.55822712153123e-05]
# Starting Epoch 90......
# Epoch [90/160], Loss: 1.0716, Train Accuracy: 0.9989
# Validation Accuracy: 0.9471
# Precision: 0.9472, Recall (Sensitivity): 0.9471, F1-score: 0.9469, AUC: 0.9920
# Epoch 90, Updated Learning Rate: [1.4644660940672634e-05]
# Starting Epoch 91......
# Epoch [91/160], Loss: 1.3064, Train Accuracy: 0.9985
# Validation Accuracy: 0.9483
# Precision: 0.9485, Recall (Sensitivity): 0.9483, F1-score: 0.9482, AUC: 0.9911
# Epoch 91, Updated Learning Rate: [1.3731281449385625e-05]
# Starting Epoch 92......
# Epoch [92/160], Loss: 1.2043, Train Accuracy: 0.9983
# Validation Accuracy: 0.9504
# Precision: 0.9505, Recall (Sensitivity): 0.9504, F1-score: 0.9503, AUC: 0.9915
# Epoch 92, Updated Learning Rate: [1.2842758726130306e-05]
# Starting Epoch 93......
# Epoch [93/160], Loss: 0.6869, Train Accuracy: 0.9990
# Validation Accuracy: 0.9517
# Precision: 0.9519, Recall (Sensitivity): 0.9517, F1-score: 0.9516, AUC: 0.9929
# Epoch 93, Updated Learning Rate: [1.1979701719998459e-05]
# Starting Epoch 94......
# Epoch [94/160], Loss: 1.7123, Train Accuracy: 0.9990
# Validation Accuracy: 0.9442
# Precision: 0.9445, Recall (Sensitivity): 0.9442, F1-score: 0.9440, AUC: 0.9910
# Epoch 94, Updated Learning Rate: [1.114270192715146e-05]
# Starting Epoch 95......
# Epoch [95/160], Loss: 1.0787, Train Accuracy: 0.9987
# Validation Accuracy: 0.9521
# Precision: 0.9524, Recall (Sensitivity): 0.9521, F1-score: 0.9520, AUC: 0.9921
# ✅ Saved Best Model!
# Epoch 95, Updated Learning Rate: [1.0332332985438241e-05]
# Starting Epoch 96......
# Epoch [96/160], Loss: 0.8652, Train Accuracy: 0.9993
# Validation Accuracy: 0.9437
# Precision: 0.9438, Recall (Sensitivity): 0.9437, F1-score: 0.9436, AUC: 0.9917
# Epoch 96, Updated Learning Rate: [9.549150281252636e-06]
# Starting Epoch 97......
# Epoch [97/160], Loss: 0.6840, Train Accuracy: 0.9991
# Validation Accuracy: 0.9525
# Precision: 0.9528, Recall (Sensitivity): 0.9525, F1-score: 0.9523, AUC: 0.9905
# ✅ Saved Best Model!
# Epoch 97, Updated Learning Rate: [8.79369056889923e-06]
# Starting Epoch 98......
# Epoch [98/160], Loss: 0.6445, Train Accuracy: 0.9994
# Validation Accuracy: 0.9471
# Precision: 0.9472, Recall (Sensitivity): 0.9471, F1-score: 0.9469, AUC: 0.9916
# Epoch 98, Updated Learning Rate: [8.066471602728807e-06]
# Starting Epoch 99......
# Epoch [99/160], Loss: 0.6468, Train Accuracy: 0.9988
# Validation Accuracy: 0.9450
# Precision: 0.9453, Recall (Sensitivity): 0.9450, F1-score: 0.9448, AUC: 0.9925
# Epoch 99, Updated Learning Rate: [7.367991782295395e-06]
# Starting Epoch 100......
# Epoch [100/160], Loss: 0.7443, Train Accuracy: 0.9988
# Validation Accuracy: 0.9479
# Precision: 0.9479, Recall (Sensitivity): 0.9479, F1-score: 0.9478, AUC: 0.9911
# Epoch 100, Updated Learning Rate: [6.698729810778068e-06]
# Starting Epoch 101......
# Epoch [101/160], Loss: 0.6418, Train Accuracy: 0.9989
# Validation Accuracy: 0.9508
# Precision: 0.9515, Recall (Sensitivity): 0.9508, F1-score: 0.9506, AUC: 0.9932
# Epoch 101, Updated Learning Rate: [6.059144366901739e-06]
# Starting Epoch 102......
# Epoch [102/160], Loss: 0.6754, Train Accuracy: 0.9990
# Validation Accuracy: 0.9446
# Precision: 0.9448, Recall (Sensitivity): 0.9446, F1-score: 0.9444, AUC: 0.9907
# Epoch 102, Updated Learning Rate: [5.449673790581613e-06]
# Starting Epoch 103......
# Epoch [103/160], Loss: 0.6300, Train Accuracy: 0.9990
# Validation Accuracy: 0.9508
# Precision: 0.9510, Recall (Sensitivity): 0.9508, F1-score: 0.9507, AUC: 0.9932
# Epoch 103, Updated Learning Rate: [4.870735782506982e-06]
# Starting Epoch 104......
# Epoch [104/160], Loss: 0.6765, Train Accuracy: 0.9987
# Validation Accuracy: 0.9496
# Precision: 0.9497, Recall (Sensitivity): 0.9496, F1-score: 0.9495, AUC: 0.9917
# Epoch 104, Updated Learning Rate: [4.322727117869953e-06]
# Starting Epoch 105......
# Epoch [105/160], Loss: 0.7220, Train Accuracy: 0.9992
# Validation Accuracy: 0.9513
# Precision: 0.9513, Recall (Sensitivity): 0.9513, F1-score: 0.9512, AUC: 0.9928
# Epoch 105, Updated Learning Rate: [3.806023374435665e-06]
# Starting Epoch 106......
# Epoch [106/160], Loss: 0.4494, Train Accuracy: 0.9994
# Validation Accuracy: 0.9513
# Precision: 0.9514, Recall (Sensitivity): 0.9513, F1-score: 0.9511, AUC: 0.9924
# Epoch 106, Updated Learning Rate: [3.3209786751399145e-06]
# Starting Epoch 107......
# Epoch [107/160], Loss: 0.4676, Train Accuracy: 0.9994
# Validation Accuracy: 0.9525
# Precision: 0.9527, Recall (Sensitivity): 0.9525, F1-score: 0.9524, AUC: 0.9928
# Epoch 107, Updated Learning Rate: [2.8679254453910857e-06]
# Starting Epoch 108......
# Epoch [108/160], Loss: 0.6193, Train Accuracy: 0.9988
# Validation Accuracy: 0.9483
# Precision: 0.9485, Recall (Sensitivity): 0.9483, F1-score: 0.9482, AUC: 0.9924
# Epoch 108, Updated Learning Rate: [2.447174185242325e-06]
# Starting Epoch 109......
# Epoch [109/160], Loss: 0.7920, Train Accuracy: 0.9988
# Validation Accuracy: 0.9492
# Precision: 0.9494, Recall (Sensitivity): 0.9492, F1-score: 0.9490, AUC: 0.9918
# Epoch 109, Updated Learning Rate: [2.0590132565903543e-06]
# Starting Epoch 110......
# Epoch [110/160], Loss: 0.7901, Train Accuracy: 0.9990
# Validation Accuracy: 0.9492
# Precision: 0.9496, Recall (Sensitivity): 0.9492, F1-score: 0.9490, AUC: 0.9920
# Epoch 110, Updated Learning Rate: [1.7037086855465854e-06]
# Starting Epoch 111......
# Epoch [111/160], Loss: 0.4855, Train Accuracy: 0.9991
# Validation Accuracy: 0.9479
# Precision: 0.9483, Recall (Sensitivity): 0.9479, F1-score: 0.9478, AUC: 0.9920
# Epoch 111, Updated Learning Rate: [1.3815039801161732e-06]
# Starting Epoch 112......
# Epoch [112/160], Loss: 0.4755, Train Accuracy: 0.9995
# Validation Accuracy: 0.9492
# Precision: 0.9497, Recall (Sensitivity): 0.9492, F1-score: 0.9490, AUC: 0.9924
# Epoch 112, Updated Learning Rate: [1.0926199633097164e-06]
# Starting Epoch 113......
# Epoch [113/160], Loss: 0.4945, Train Accuracy: 0.9992
# Validation Accuracy: 0.9521
# Precision: 0.9523, Recall (Sensitivity): 0.9521, F1-score: 0.9520, AUC: 0.9920
# Epoch 113, Updated Learning Rate: [8.372546218022752e-07]
# Starting Epoch 114......
# Epoch [114/160], Loss: 0.6132, Train Accuracy: 0.9990
# Validation Accuracy: 0.9513
# Precision: 0.9515, Recall (Sensitivity): 0.9513, F1-score: 0.9511, AUC: 0.9925
# Epoch 114, Updated Learning Rate: [6.155829702431174e-07]
# Starting Epoch 115......
# Epoch [115/160], Loss: 0.5286, Train Accuracy: 0.9991
# Validation Accuracy: 0.9483
# Precision: 0.9485, Recall (Sensitivity): 0.9483, F1-score: 0.9483, AUC: 0.9932
# Epoch 115, Updated Learning Rate: [4.277569313094812e-07]
# Starting Epoch 116......
# Epoch [116/160], Loss: 0.5524, Train Accuracy: 0.9992
# Validation Accuracy: 0.9492
# Precision: 0.9495, Recall (Sensitivity): 0.9492, F1-score: 0.9491, AUC: 0.9922
# Epoch 116, Updated Learning Rate: [2.739052315863302e-07]
# Starting Epoch 117......
# Epoch [117/160], Loss: 0.7050, Train Accuracy: 0.9990
# Validation Accuracy: 0.9467
# Precision: 0.9468, Recall (Sensitivity): 0.9467, F1-score: 0.9465, AUC: 0.9917
# Epoch 117, Updated Learning Rate: [1.5413331334360192e-07]
# Starting Epoch 118......
# Epoch [118/160], Loss: 0.4407, Train Accuracy: 0.9994
# Validation Accuracy: 0.9479
# Precision: 0.9482, Recall (Sensitivity): 0.9479, F1-score: 0.9478, AUC: 0.9930
# Epoch 118, Updated Learning Rate: [6.85232622713084e-08]
# Starting Epoch 119......
# Epoch [119/160], Loss: 0.3564, Train Accuracy: 0.9996
# Validation Accuracy: 0.9479
# Precision: 0.9481, Recall (Sensitivity): 0.9479, F1-score: 0.9478, AUC: 0.9910
# Epoch 119, Updated Learning Rate: [1.7133751222137017e-08]
# Starting Epoch 120......
# Epoch [120/160], Loss: 0.5911, Train Accuracy: 0.9996
# Validation Accuracy: 0.9504
# Precision: 0.9505, Recall (Sensitivity): 0.9504, F1-score: 0.9503, AUC: 0.9925
# Epoch 120, Updated Learning Rate: [0.0]
# Starting Epoch 121......
# Epoch [121/160], Loss: 0.2966, Train Accuracy: 0.9996
# Validation Accuracy: 0.9558
# Precision: 0.9560, Recall (Sensitivity): 0.9558, F1-score: 0.9557, AUC: 0.9932
# ✅ Saved Best Model!
# Epoch 121, Updated Learning Rate: [1.7133751222137007e-08]
# Starting Epoch 122......
# Epoch [122/160], Loss: 0.3807, Train Accuracy: 0.9996
# Validation Accuracy: 0.9529
# Precision: 0.9531, Recall (Sensitivity): 0.9529, F1-score: 0.9528, AUC: 0.9923
# Epoch 122, Updated Learning Rate: [6.852326227130834e-08]
# Starting Epoch 123......
# Epoch [123/160], Loss: 0.3543, Train Accuracy: 0.9995
# Validation Accuracy: 0.9487
# Precision: 0.9492, Recall (Sensitivity): 0.9487, F1-score: 0.9486, AUC: 0.9925
# Epoch 123, Updated Learning Rate: [1.5413331334360182e-07]
# Starting Epoch 124......
# Epoch [124/160], Loss: 0.5598, Train Accuracy: 0.9994
# Validation Accuracy: 0.9504
# Precision: 0.9506, Recall (Sensitivity): 0.9504, F1-score: 0.9503, AUC: 0.9916
# Epoch 124, Updated Learning Rate: [2.7390523158633e-07]
# Starting Epoch 125......
# Epoch [125/160], Loss: 0.4653, Train Accuracy: 0.9994
# Validation Accuracy: 0.9483
# Precision: 0.9485, Recall (Sensitivity): 0.9483, F1-score: 0.9481, AUC: 0.9911
# Epoch 125, Updated Learning Rate: [4.2775693130947534e-07]
# Starting Epoch 126......
# Epoch [126/160], Loss: 0.5301, Train Accuracy: 0.9995
# Validation Accuracy: 0.9467
# Precision: 0.9467, Recall (Sensitivity): 0.9467, F1-score: 0.9466, AUC: 0.9923
# Epoch 126, Updated Learning Rate: [6.155829702431115e-07]
# Starting Epoch 127......
# Epoch [127/160], Loss: 0.4417, Train Accuracy: 0.9992
# Validation Accuracy: 0.9550
# Precision: 0.9551, Recall (Sensitivity): 0.9550, F1-score: 0.9549, AUC: 0.9916
# Epoch 127, Updated Learning Rate: [8.372546218022693e-07]
# Starting Epoch 128......
# Epoch [128/160], Loss: 0.7555, Train Accuracy: 0.9991
# Validation Accuracy: 0.9496
# Precision: 0.9498, Recall (Sensitivity): 0.9496, F1-score: 0.9495, AUC: 0.9911
# Epoch 128, Updated Learning Rate: [1.0926199633097157e-06]
# Starting Epoch 129......
# Epoch [129/160], Loss: 0.8457, Train Accuracy: 0.9990
# Validation Accuracy: 0.9467
# Precision: 0.9468, Recall (Sensitivity): 0.9467, F1-score: 0.9466, AUC: 0.9918
# Epoch 129, Updated Learning Rate: [1.3815039801161666e-06]
# Starting Epoch 130......
# Epoch [130/160], Loss: 0.5156, Train Accuracy: 0.9992
# Validation Accuracy: 0.9550
# Precision: 0.9553, Recall (Sensitivity): 0.9550, F1-score: 0.9549, AUC: 0.9920
# Epoch 130, Updated Learning Rate: [1.7037086855465787e-06]
# Starting Epoch 131......
# Epoch [131/160], Loss: 0.4919, Train Accuracy: 0.9994
# Validation Accuracy: 0.9487
# Precision: 0.9489, Recall (Sensitivity): 0.9487, F1-score: 0.9487, AUC: 0.9927
# Epoch 131, Updated Learning Rate: [2.059013256590347e-06]
# Starting Epoch 132......
# Epoch [132/160], Loss: 0.5545, Train Accuracy: 0.9988
# Validation Accuracy: 0.9463
# Precision: 0.9465, Recall (Sensitivity): 0.9463, F1-score: 0.9462, AUC: 0.9914
# Epoch 132, Updated Learning Rate: [2.447174185242318e-06]
# Starting Epoch 133......
# Epoch [133/160], Loss: 0.2748, Train Accuracy: 0.9995
# Validation Accuracy: 0.9508
# Precision: 0.9510, Recall (Sensitivity): 0.9508, F1-score: 0.9508, AUC: 0.9921
# Epoch 133, Updated Learning Rate: [2.8679254453910785e-06]
# Starting Epoch 134......
# Epoch [134/160], Loss: 0.4072, Train Accuracy: 0.9995
# Validation Accuracy: 0.9467
# Precision: 0.9469, Recall (Sensitivity): 0.9467, F1-score: 0.9465, AUC: 0.9917
# Epoch 134, Updated Learning Rate: [3.3209786751399077e-06]
# Starting Epoch 135......
# Epoch [135/160], Loss: 0.4260, Train Accuracy: 0.9995
# Validation Accuracy: 0.9500
# Precision: 0.9502, Recall (Sensitivity): 0.9500, F1-score: 0.9499, AUC: 0.9918
# Epoch 135, Updated Learning Rate: [3.8060233744356578e-06]
# Starting Epoch 136......
# Epoch [136/160], Loss: 0.5754, Train Accuracy: 0.9994
# Validation Accuracy: 0.9513
# Precision: 0.9514, Recall (Sensitivity): 0.9513, F1-score: 0.9511, AUC: 0.9919
# Epoch 136, Updated Learning Rate: [4.322727117869956e-06]
# Starting Epoch 137......
# Epoch [137/160], Loss: 0.3022, Train Accuracy: 0.9996
# Validation Accuracy: 0.9467
# Precision: 0.9469, Recall (Sensitivity): 0.9467, F1-score: 0.9465, AUC: 0.9923
# Epoch 137, Updated Learning Rate: [4.870735782506973e-06]
# Starting Epoch 138......
# Epoch [138/160], Loss: 0.3569, Train Accuracy: 0.9995
# Validation Accuracy: 0.9496
# Precision: 0.9498, Recall (Sensitivity): 0.9496, F1-score: 0.9494, AUC: 0.9917
# Epoch 138, Updated Learning Rate: [5.449673790581604e-06]
# Starting Epoch 139......
# Epoch [139/160], Loss: 0.8991, Train Accuracy: 0.9992
# Validation Accuracy: 0.9483
# Precision: 0.9485, Recall (Sensitivity): 0.9483, F1-score: 0.9482, AUC: 0.9911
# Epoch 139, Updated Learning Rate: [6.059144366901729e-06]
# Starting Epoch 140......
# Epoch [140/160], Loss: 1.4877, Train Accuracy: 0.9989
# Validation Accuracy: 0.9537
# Precision: 0.9538, Recall (Sensitivity): 0.9537, F1-score: 0.9537, AUC: 0.9922
# Epoch 140, Updated Learning Rate: [6.698729810778057e-06]
# Starting Epoch 141......
# Epoch [141/160], Loss: 0.5439, Train Accuracy: 0.9993
# Validation Accuracy: 0.9475
# Precision: 0.9475, Recall (Sensitivity): 0.9475, F1-score: 0.9474, AUC: 0.9917
# Epoch 141, Updated Learning Rate: [7.367991782295382e-06]
# Starting Epoch 142......
# Epoch [142/160], Loss: 0.5287, Train Accuracy: 0.9994
# Validation Accuracy: 0.9508
# Precision: 0.9510, Recall (Sensitivity): 0.9508, F1-score: 0.9508, AUC: 0.9914
# Epoch 142, Updated Learning Rate: [8.066471602728795e-06]
# Starting Epoch 143......
# Epoch [143/160], Loss: 0.6157, Train Accuracy: 0.9993
# Validation Accuracy: 0.9487
# Precision: 0.9490, Recall (Sensitivity): 0.9487, F1-score: 0.9486, AUC: 0.9923
# Epoch 143, Updated Learning Rate: [8.793690568899218e-06]
# Starting Epoch 144......
# Epoch [144/160], Loss: 0.3621, Train Accuracy: 0.9995
# Validation Accuracy: 0.9508
# Precision: 0.9510, Recall (Sensitivity): 0.9508, F1-score: 0.9507, AUC: 0.9921
# Epoch 144, Updated Learning Rate: [9.549150281252618e-06]
# Starting Epoch 145......
# Epoch [145/160], Loss: 0.4772, Train Accuracy: 0.9992
# Validation Accuracy: 0.9521
# Precision: 0.9523, Recall (Sensitivity): 0.9521, F1-score: 0.9520, AUC: 0.9932
# Epoch 145, Updated Learning Rate: [1.0332332985438226e-05]
# Starting Epoch 146......
# Epoch [146/160], Loss: 0.7807, Train Accuracy: 0.9990
# Validation Accuracy: 0.9487
# Precision: 0.9488, Recall (Sensitivity): 0.9487, F1-score: 0.9486, AUC: 0.9919
# Epoch 146, Updated Learning Rate: [1.1142701927151444e-05]
# Starting Epoch 147......
# Epoch [147/160], Loss: 0.6093, Train Accuracy: 0.9991
# Validation Accuracy: 0.9521
# Precision: 0.9524, Recall (Sensitivity): 0.9521, F1-score: 0.9520, AUC: 0.9926
# Epoch 147, Updated Learning Rate: [1.1979701719998442e-05]
# Starting Epoch 148......
# Epoch [148/160], Loss: 0.6012, Train Accuracy: 0.9995
# Validation Accuracy: 0.9446
# Precision: 0.9447, Recall (Sensitivity): 0.9446, F1-score: 0.9445, AUC: 0.9919
# Epoch 148, Updated Learning Rate: [1.2842758726130282e-05]
# Starting Epoch 149......
# Epoch [149/160], Loss: 0.6409, Train Accuracy: 0.9989
# Validation Accuracy: 0.9517
# Precision: 0.9519, Recall (Sensitivity): 0.9517, F1-score: 0.9515, AUC: 0.9915
# Epoch 149, Updated Learning Rate: [1.37312814493856e-05]
# Starting Epoch 150......
# Epoch [150/160], Loss: 0.6902, Train Accuracy: 0.9992
# Validation Accuracy: 0.9442
# Precision: 0.9446, Recall (Sensitivity): 0.9442, F1-score: 0.9440, AUC: 0.9912
# Epoch 150, Updated Learning Rate: [1.4644660940672607e-05]
# Starting Epoch 151......
# Epoch [151/160], Loss: 1.2789, Train Accuracy: 0.9983
# Validation Accuracy: 0.9496
# Precision: 0.9499, Recall (Sensitivity): 0.9496, F1-score: 0.9494, AUC: 0.9909
# Epoch 151, Updated Learning Rate: [1.558227121531227e-05]
# Starting Epoch 152......
# Epoch [152/160], Loss: 0.8773, Train Accuracy: 0.9992
# Validation Accuracy: 0.9500
# Precision: 0.9502, Recall (Sensitivity): 0.9500, F1-score: 0.9498, AUC: 0.9918
# Epoch 152, Updated Learning Rate: [1.6543469682057062e-05]
# Starting Epoch 153......
# Epoch [153/160], Loss: 0.6897, Train Accuracy: 0.9992
# Validation Accuracy: 0.9504
# Precision: 0.9506, Recall (Sensitivity): 0.9504, F1-score: 0.9503, AUC: 0.9926
# Epoch 153, Updated Learning Rate: [1.7527597583490812e-05]
# Starting Epoch 154......
# Epoch [154/160], Loss: 1.2021, Train Accuracy: 0.9987
# Validation Accuracy: 0.9521
# Precision: 0.9525, Recall (Sensitivity): 0.9521, F1-score: 0.9519, AUC: 0.9921
# Epoch 154, Updated Learning Rate: [1.853398044750809e-05]
# Starting Epoch 155......
# Epoch [155/160], Loss: 0.7842, Train Accuracy: 0.9992
# Validation Accuracy: 0.9458
# Precision: 0.9461, Recall (Sensitivity): 0.9458, F1-score: 0.9458, AUC: 0.9916
# Epoch 155, Updated Learning Rate: [1.9561928549563938e-05]
# Starting Epoch 156......
# Epoch [156/160], Loss: 1.1769, Train Accuracy: 0.9984
# Validation Accuracy: 0.9421
# Precision: 0.9425, Recall (Sensitivity): 0.9421, F1-score: 0.9419, AUC: 0.9894
# Epoch 156, Updated Learning Rate: [2.0610737385376315e-05]
# Starting Epoch 157......
# Epoch [157/160], Loss: 0.6522, Train Accuracy: 0.9990
# Validation Accuracy: 0.9454
# Precision: 0.9456, Recall (Sensitivity): 0.9454, F1-score: 0.9454, AUC: 0.9904
# Epoch 157, Updated Learning Rate: [2.1679688153758332e-05]
# Starting Epoch 158......
# Epoch [158/160], Loss: 1.0730, Train Accuracy: 0.9984
# Validation Accuracy: 0.9483
# Precision: 0.9488, Recall (Sensitivity): 0.9483, F1-score: 0.9481, AUC: 0.9916
# Epoch 158, Updated Learning Rate: [2.2768048249248624e-05]
# Starting Epoch 159......
# Epoch [159/160], Loss: 1.5030, Train Accuracy: 0.9983
# Validation Accuracy: 0.9463
# Precision: 0.9469, Recall (Sensitivity): 0.9463, F1-score: 0.9460, AUC: 0.9921
# Epoch 159, Updated Learning Rate: [2.3875071764202542e-05]
# Starting Epoch 160......
# Epoch [160/160], Loss: 2.0796, Train Accuracy: 0.9976
# Validation Accuracy: 0.9387
# Precision: 0.9393, Recall (Sensitivity): 0.9387, F1-score: 0.9387, AUC: 0.9902
# Epoch 160, Updated Learning Rate: [2.499999999999995e-05]
# ✅ Training Completed! Final Model Saved.

# %% [markdown]
# ### 📦 Test

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import seaborn as sns
import torch

# Set model to evaluation mode
model.eval()
true_labels, pred_labels, pred_probs = [], [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)  # Convert logits to probabilities

        pred_labels.extend(outputs.argmax(dim=1).cpu().numpy())  # Predicted class
        true_labels.extend(labels.cpu().numpy())  # True class
        pred_probs.extend(probs.cpu().numpy())  # Store all class probabilities

# Convert to NumPy arrays
true_labels = np.array(true_labels)
pred_labels = np.array(pred_labels)
pred_probs = np.array(pred_probs)  # Shape (num_samples, num_classes)

# Explicitly Binarize Labels for Multi-Class ROC-AUC
true_labels_bin = label_binarize(true_labels, classes=[0, 1, 2, 3])

# Compute Multi-Class ROC-AUC
roc_auc = roc_auc_score(true_labels_bin, pred_probs, multi_class='ovr')
print(f"✅ **Multiclass ROC-AUC Score:** {roc_auc:.4f}")

# Generate ROC Curve (For Class 1)
fpr, tpr, _ = roc_curve(true_labels_bin[:, 1], pred_probs[:, 1])
plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], '--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.title('ROC Curve')
plt.savefig('roc_curve.png')
plt.show()

# Classification Report
target_names = ['Benign', 'Intermediate-Benign', 'Intermediate-Malignant', 'Malignant']
print(classification_report(true_labels, pred_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, pred_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Confusion Matrix")
plt.savefig('confusion_matrix.png')
plt.show()
# Out:
# ✅ **Multiclass ROC-AUC Score:** 0.9933
#                         precision    recall  f1-score   support
#
#                 Benign       0.94      0.94      0.94      1050
#    Intermediate-Benign       0.92      0.96      0.94       450
# Intermediate-Malignant       0.98      0.97      0.97       150
#              Malignant       0.94      0.91      0.92       750
#
#               accuracy                           0.94      2400
#              macro avg       0.94      0.95      0.94      2400
#           weighted avg       0.94      0.94      0.94      2400
